# %%
#!/usr/bin/env python3

# %% [markdown]
# This file illustrates how you might experiment with the HMM interface.
# You can paste these commands in at the Python prompt, or execute `test_en.py` directly.
# A notebook interface is nicer than the plain Python prompt, so we provide
# a notebook version of this file as `test_en.ipynb`, which you can open with
# `jupyter` or with Visual Studio `code` (run it with the `nlp-class` kernel).

# %%
import logging
import math
import os
from pathlib import Path

# %%
from corpus import TaggedCorpus
from eval import eval_tagging, model_cross_entropy, viterbi_error_rate
from hmm import HiddenMarkovModel
from crf import ConditionalRandomField

# %% [markdown]
# Set up logging.

# %%
logging.root.setLevel(level=logging.INFO)
log = logging.getLogger("test_en")       # For usage, see findsim.py in earlier assignment.
logging.basicConfig(format="%(levelname)s : %(message)s", level=logging.INFO)  # could change INFO to DEBUG

# %% [markdown]
# Switch working directory to the directory where the data live.  You may need to edit this line.

# %%
os.chdir("../data")

# %%
entrain = TaggedCorpus(Path("ensup"), Path("enraw"))                               # all training
ensup =   TaggedCorpus(Path("ensup"), tagset=entrain.tagset, vocab=entrain.vocab)  # supervised training
endev =   TaggedCorpus(Path("endev"), tagset=entrain.tagset, vocab=entrain.vocab)  # evaluation
print(f"{len(entrain)=}  {len(ensup)=}  {len(endev)=}")
# Out:
# INFO : Read 191873 tokens from ensup, enraw
# INFO : Created 26 tag types
# INFO : Created 18461 word types
# len(entrain)=8064  len(ensup)=4051  len(endev)=996

# %%
known_vocab = TaggedCorpus(Path("ensup")).vocab    # words seen with supervised tags; used in evaluation
log.info(f"Tagset: f{list(entrain.tagset)}")
# Out:
# INFO : Read 95936 tokens from ensup
# INFO : Created 26 tag types
# INFO : Created 12466 word types
# INFO : Tagset: f['W', 'J', 'N', 'C', 'V', 'I', 'D', ',', 'M', 'P', '.', 'E', 'R', '`', "'", 'T', '$', ':', '-', '#', 'S', 'F', 'U', 'L', '_EOS_TAG_', '_BOS_TAG_']

# %% [markdown]
# Make an HMM.  Let's do some pre-training to approximately maximize the
# regularized log-likelihood on supervised training data.  In other words, the
# probabilities at the M step will just be supervised count ratios.
#
# On each epoch, you will see two progress bars: first it collects counts from
# all the sentences (E step), and then after the M step, it evaluates the loss
# function, which is the (unregularized) cross-entropy on the training set.
#
# The parameters don't actually matter during the E step because there are no
# hidden tags to impute.  The first M step will jump right to the optimal
# solution.  The code will try a second epoch with the revised parameters, but
# the result will be identical, so it will detect convergence and stop.
#
# We arbitrarily choose λ=1 for our add-λ smoothing at the M step, but it would
# be better to search for the best value of this hyperparameter.

# %%
log.info("*** Hidden Markov Model (HMM)")
hmm = HiddenMarkovModel(entrain.tagset, entrain.vocab)  # randomly initialized parameters  
loss_sup = lambda model: model_cross_entropy(model, eval_corpus=ensup)
hmm.train(corpus=ensup, loss=loss_sup, λ=1.0,
          save_path="ensup_hmm.pkl")
# Out:
# INFO : *** Hidden Markov Model (HMM)
# 100%|██████████| 4051/4051 [00:02<00:00, 1596.98it/s]
# INFO : Cross-entropy: 12.6445 nats (= perplexity 310045.271)
# 100%|██████████| 4051/4051 [00:07<00:00, 532.39it/s]
# 100%|██████████| 4051/4051 [00:02<00:00, 1713.17it/s]
# INFO : Cross-entropy: 7.4503 nats (= perplexity 1720.395)
# 100%|██████████| 4051/4051 [00:07<00:00, 541.35it/s]
# 100%|██████████| 4051/4051 [00:02<00:00, 1701.54it/s]
# INFO : Cross-entropy: 7.4503 nats (= perplexity 1720.403)
# INFO : Saved model to ensup_hmm.pkl

# %% [markdown]
# Now let's throw in the unsupervised training data as well, and continue
# training as before, in order to increase the regularized log-likelihood on
# this larger, semi-supervised training set.  It's now the *incomplete-data*
# log-likelihood.
#
# This time, we'll use a different evaluation loss function: we'll stop when the
# *tagging error rate* on a held-out dev set stops getting better.  Also, the
# implementation of this loss function (`viterbi_error_rate`) includes a helpful
# side effect: it logs the *cross-entropy* on the held-out dataset as well, just
# for your information.
#
# We hope that held-out tagging accuracy will go up for a little bit before it
# goes down again (see Merialdo 1994). (Log-likelihood on training data will
# continue to improve, and that improvement may generalize to held-out
# cross-entropy.  But getting accuracy to increase is harder.)

# %%
hmm = HiddenMarkovModel.load("ensup_hmm.pkl")  # reset to supervised model (in case you're re-executing this bit)
loss_dev = lambda model: viterbi_error_rate(model, eval_corpus=endev, 
                                            known_vocab=known_vocab)
hmm.train(corpus=entrain, loss=loss_dev, λ=1.0,
          save_path="entrain_hmm.pkl")
# Out:
# INFO : Loaded model from ensup_hmm.pkl
# 100%|██████████| 996/996 [00:00<00:00, 1154.84it/s]
# INFO : Cross-entropy: 7.5993 nats (= perplexity 1996.797)
# 100%|██████████| 996/996 [00:01<00:00, 626.35it/s]
# INFO : Tagging accuracy: all: 88.663%, known: 93.059%, seen: 44.108%, novel: 42.734%
# 100%|██████████| 8064/8064 [00:16<00:00, 481.14it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1245.36it/s]
# INFO : Cross-entropy: 7.3485 nats (= perplexity 1553.848)
# 100%|██████████| 996/996 [00:01<00:00, 670.06it/s]
# INFO : Tagging accuracy: all: 87.031%, known: 91.397%, seen: 45.791%, novel: 40.225%
# INFO : Saved model to entrain_hmm.pkl

# %% [markdown]
# You can also retry the above workflow where you start with a worse supervised
# model (like Merialdo).  Does EM help more in that case?  It's easiest to rerun
# exactly the code above, but first make the `ensup` file smaller by copying
# `ensup-tiny` over it.  `ensup-tiny` is only 25 sentences (that happen to cover
# all tags in `endev`).  Back up your old `ensup` and your old `*.pkl` models
# before you do this.

# %% [markdown]
# More detailed look at the first 10 sentences in the held-out corpus,
# including Viterbi tagging.

# %%
def look_at_your_data(model, dev, N):
    for m, sentence in enumerate(dev):
        if m >= N: break
        viterbi = model.viterbi_tagging(sentence.desupervise(), endev)
        counts = eval_tagging(predicted=viterbi, gold=sentence, 
                              known_vocab=known_vocab)
        num = counts['NUM', 'ALL']
        denom = counts['DENOM', 'ALL']
        
        log.info(f"Gold:    {sentence}")
        log.info(f"Viterbi: {viterbi}")
        log.info(f"Loss:    {denom - num}/{denom}")
        xent = -model.logprob(sentence, endev) / len(sentence)  # measured in nats
        log.info(f"Cross-entropy: {xent/math.log(2)} nats (= perplexity {math.exp(xent)})\n---")

# %%
look_at_your_data(hmm, endev, 10)
# Out:
# INFO : Gold:    ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/N this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/N added/V ,/, ``/` and/C that/D means/V virtually/R everyone/N who/W works/V here/R ./.
# INFO : Viterbi: ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/N this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/T added/V ,/, ``/` and/C that/I means/V virtually/R everyone/, who/W works/V here/R ./.
# INFO : Loss:    3/34
# INFO : Cross-entropy: 10.61779499053955 nats (= perplexity 1571.3564102110174)
# ---
# INFO : Gold:    I/P was/V _OOV_/V to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/N ``/` _OOV_/N 's/P _OOV_/N _OOV_/N ./. ''/'
# INFO : Viterbi: I/P was/V _OOV_/V to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/, ``/` _OOV_/P 's/V _OOV_/D _OOV_/N ./. ''/'
# INFO : Loss:    4/21
# INFO : Cross-entropy: 10.876285552978516 nats (= perplexity 1879.69911304983)
# ---
# INFO : Gold:    It/P is/V the/D _OOV_/J guerrillas/N who/W are/V aligned/V with/I the/D drug/N traffickers/N ,/, not/R the/D left/J _OOV_/N ./.
# INFO : Viterbi: It/P is/V the/D _OOV_/N guerrillas/, who/W are/V aligned/R with/I the/D drug/N traffickers/N ,/, not/R the/D left/J _OOV_/N ./.
# INFO : Loss:    3/18
# INFO : Cross-entropy: 9.650657653808594 nats (= perplexity 803.7805517322801)
# ---
# INFO : Gold:    This/D information/N was/V _OOV_/V from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Viterbi: This/D information/N was/V _OOV_/R from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Loss:    1/13
# INFO : Cross-entropy: 9.34328556060791 nats (= perplexity 649.5449924622674)
# ---
# INFO : Gold:    _OOV_/J _OOV_/J government/N _OOV_/N of/I the/D ``/` _OOV_/F ''/' was/V due/J to/T the/D drug/N _OOV_/N '/P history/N of/I _OOV_/V out/R _OOV_/N in/I the/D _OOV_/N ./.
# INFO : Viterbi: _OOV_/D _OOV_/J government/N _OOV_/N of/I the/D ``/N _OOV_/, ''/' was/V due/J to/T the/D drug/N _OOV_/I '/P history/N of/I _OOV_/N out/I _OOV_/N in/I the/D _OOV_/N ./.
# INFO : Loss:    6/25
# INFO : Cross-entropy: 10.975038528442383 nats (= perplexity 2012.870256639555)
# ---
# INFO : Gold:    Mary/N _OOV_/N Palo/N Alto/N ,/, Calif/N ./.
# INFO : Viterbi: Mary/N _OOV_/I Palo/D Alto/N ,/, Calif/N ./.
# INFO : Loss:    2/7
# INFO : Cross-entropy: 10.526596069335938 nats (= perplexity 1475.0993990210206)
# ---
# INFO : Gold:    I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/R well/R as/I other/J U.S./N news/N publications/N of/I like/J mind/N -RRB-/- should/M put/V its/P money/N where/W its/P mouth/N is/V :/: _OOV_/V computer/N equipment/N to/T replace/V that/I damaged/V at/I El/N _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/N _OOV_/N journalists/N ./.
# INFO : Viterbi: I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/I well/R as/I other/J U.S./N news/N publications/N of/I like/I mind/N -RRB-/N should/M put/V its/P money/N where/W its/P mouth/M is/V :/I _OOV_/D computer/N equipment/N to/T replace/V that/I damaged/N at/I El/D _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/D _OOV_/J journalists/N ./.
# INFO : Loss:    10/53
# INFO : Cross-entropy: 11.649870872497559 nats (= perplexity 3213.368842789746)
# ---
# INFO : Gold:    Perhaps/R an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/V ''/' El/N _OOV_/N journalists/N and/C staff/N by/I paying/V for/I added/V security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Viterbi: Perhaps/I an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/F ''/' El/V _OOV_/T journalists/$ and/C staff/N by/I paying/V for/I added/J security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Loss:    6/27
# INFO : Cross-entropy: 11.456055641174316 nats (= perplexity 2809.4189341157016)
# ---
# INFO : Gold:    _OOV_/V El/N _OOV_/N 's/P courage/N with/I real/J support/N ./.
# INFO : Viterbi: _OOV_/D El/N _OOV_/I 's/P courage/N with/I real/J support/N ./.
# INFO : Loss:    2/9
# INFO : Cross-entropy: 10.91425609588623 nats (= perplexity 1929.8268191741217)
# ---
# INFO : Gold:    Douglas/N B./N Evans/N
# INFO : Viterbi: Douglas/D B./N Evans/.
# INFO : Loss:    2/3
# INFO : Cross-entropy: 11.670408248901367 nats (= perplexity 3259.4398878531224)
# ---

# %% [markdown]
# Now let's try supervised training of a CRF (this doesn't use the unsupervised
# part of the data, so it is comparable to the supervised pre-training we did
# for the HMM).  We will use SGD to approximately maximize the regularized
# log-likelihood.
#
# As with the semi-supervised HMM training, we'll periodically evaluate the
# tagging accuracy (and also print the cross-entropy) on a held-out dev set.
# We use the default `eval_interval` and `tolerance`.  If you want to stop
# sooner, then you could increase the `tolerance` so the training method decides
# sooner that it has converged.
#
# We arbitrarily choose reg = 1.0 for L2 regularization, learning rate = 0.05,
# and a minibatch size of 10, but it would be better to search for the best
# value of these hyperparameters.
#
# Note that the logger reports the CRF's *conditional* cross-entropy, log p(tags
# | words) / n.  This is much lower than the HMM's *joint* cross-entropy log
# p(tags, words) / n, but that doesn't mean the CRF is worse at tagging.  The
# CRF is just predicting less information.

# %%
log.info("*** Conditional Random Field (CRF)\n")
crf = ConditionalRandomField(entrain.tagset, entrain.vocab)  # randomly initialized parameters  
crf.train(corpus=ensup, loss=loss_dev, reg=1.0, lr=0.05, minibatch_size=10,
          save_path="ensup_crf.pkl")
# Out:
# INFO : *** Conditional Random Field (CRF)
#
# 100%|██████████| 996/996 [00:00<00:00, 1051.44it/s]
# INFO : Cross-entropy: 3.0503 nats (= perplexity 21.122)
# 100%|██████████| 996/996 [00:01<00:00, 841.06it/s]
# INFO : Tagging accuracy: all: 4.652%, known: 4.359%, seen: 4.545%, novel: 8.917%
# 100%|██████████| 500/500 [00:02<00:00, 231.79it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1019.96it/s]
# INFO : Cross-entropy: 0.9114 nats (= perplexity 2.488)
# 100%|██████████| 996/996 [00:01<00:00, 870.93it/s]
# INFO : Tagging accuracy: all: 72.412%, known: 73.495%, seen: 57.744%, novel: 62.550%
# 100%|██████████| 500/500 [00:02<00:00, 240.54it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1049.40it/s]
# INFO : Cross-entropy: 0.7515 nats (= perplexity 2.120)
# 100%|██████████| 996/996 [00:01<00:00, 853.76it/s]
# INFO : Tagging accuracy: all: 75.176%, known: 76.906%, seen: 56.397%, novel: 57.596%
# 100%|██████████| 500/500 [00:02<00:00, 242.84it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1060.51it/s]
# INFO : Cross-entropy: 0.6581 nats (= perplexity 1.931)
# 100%|██████████| 996/996 [00:01<00:00, 846.16it/s]
# INFO : Tagging accuracy: all: 78.784%, known: 80.344%, seen: 61.785%, novel: 62.946%
# 100%|██████████| 500/500 [00:01<00:00, 255.58it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1061.32it/s]
# INFO : Cross-entropy: 0.6043 nats (= perplexity 1.830)
# 100%|██████████| 996/996 [00:01<00:00, 850.13it/s]
# INFO : Tagging accuracy: all: 80.651%, known: 82.263%, seen: 62.121%, novel: 64.663%
# 100%|██████████| 500/500 [00:02<00:00, 241.78it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1046.95it/s]
# INFO : Cross-entropy: 0.5692 nats (= perplexity 1.767)
# 100%|██████████| 996/996 [00:01<00:00, 855.68it/s]
# INFO : Tagging accuracy: all: 80.425%, known: 81.887%, seen: 64.310%, novel: 65.654%
# 100%|██████████| 500/500 [00:02<00:00, 246.62it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1040.68it/s]
# INFO : Cross-entropy: 0.5370 nats (= perplexity 1.711)
# 100%|██████████| 996/996 [00:01<00:00, 850.73it/s]
# INFO : Tagging accuracy: all: 81.565%, known: 83.165%, seen: 64.141%, novel: 65.324%
# 100%|██████████| 500/500 [00:02<00:00, 249.37it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1054.63it/s]
# INFO : Cross-entropy: 0.5110 nats (= perplexity 1.667)
# 100%|██████████| 996/996 [00:01<00:00, 853.22it/s]
# INFO : Tagging accuracy: all: 83.540%, known: 85.394%, seen: 62.458%, novel: 65.059%
# 100%|██████████| 500/500 [00:02<00:00, 243.83it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1038.49it/s]
# INFO : Cross-entropy: 0.4888 nats (= perplexity 1.630)
# 100%|██████████| 996/996 [00:01<00:00, 857.19it/s]
# INFO : Tagging accuracy: all: 84.216%, known: 86.095%, seen: 63.131%, novel: 65.390%
# 100%|██████████| 500/500 [00:01<00:00, 250.37it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1059.91it/s]
# INFO : Cross-entropy: 0.4724 nats (= perplexity 1.604)
# 100%|██████████| 996/996 [00:01<00:00, 858.45it/s]
# INFO : Tagging accuracy: all: 84.613%, known: 86.539%, seen: 62.963%, novel: 65.324%
# 100%|██████████| 500/500 [00:02<00:00, 246.13it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1042.35it/s]
# INFO : Cross-entropy: 0.4587 nats (= perplexity 1.582)
# 100%|██████████| 996/996 [00:01<00:00, 846.22it/s]
# INFO : Tagging accuracy: all: 84.893%, known: 86.942%, seen: 62.458%, novel: 64.135%
# 100%|██████████| 500/500 [00:02<00:00, 246.44it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1060.09it/s]
# INFO : Cross-entropy: 0.4442 nats (= perplexity 1.559)
# 100%|██████████| 996/996 [00:01<00:00, 843.73it/s]
# INFO : Tagging accuracy: all: 85.244%, known: 87.240%, seen: 62.795%, novel: 65.258%
# 100%|██████████| 500/500 [00:02<00:00, 247.68it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1073.88it/s]
# INFO : Cross-entropy: 0.4345 nats (= perplexity 1.544)
# 100%|██████████| 996/996 [00:01<00:00, 862.11it/s]
# INFO : Tagging accuracy: all: 85.507%, known: 87.450%, seen: 63.805%, novel: 65.984%
# 100%|██████████| 500/500 [00:01<00:00, 250.33it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1061.72it/s]
# INFO : Cross-entropy: 0.4225 nats (= perplexity 1.526)
# 100%|██████████| 996/996 [00:01<00:00, 858.21it/s]
# INFO : Tagging accuracy: all: 85.962%, known: 87.936%, seen: 63.636%, novel: 66.248%
# 100%|██████████| 500/500 [00:02<00:00, 240.51it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1047.40it/s]
# INFO : Cross-entropy: 0.4163 nats (= perplexity 1.516)
# 100%|██████████| 996/996 [00:01<00:00, 854.78it/s]
# INFO : Tagging accuracy: all: 85.916%, known: 87.849%, seen: 64.141%, novel: 66.579%
# 100%|██████████| 500/500 [00:02<00:00, 245.29it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1039.78it/s]
# INFO : Cross-entropy: 0.4081 nats (= perplexity 1.504)
# 100%|██████████| 996/996 [00:01<00:00, 848.10it/s]
# INFO : Tagging accuracy: all: 86.634%, known: 88.586%, seen: 64.646%, novel: 67.107%
# 100%|██████████| 500/500 [00:02<00:00, 244.58it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1031.19it/s]
# INFO : Cross-entropy: 0.3987 nats (= perplexity 1.490)
# 100%|██████████| 996/996 [00:01<00:00, 868.64it/s]
# INFO : Tagging accuracy: all: 86.275%, known: 88.480%, seen: 63.131%, novel: 63.540%
# 100%|██████████| 500/500 [00:02<00:00, 249.77it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1062.86it/s]
# INFO : Cross-entropy: 0.3909 nats (= perplexity 1.478)
# 100%|██████████| 996/996 [00:01<00:00, 875.00it/s]
# INFO : Tagging accuracy: all: 86.835%, known: 88.897%, seen: 62.963%, novel: 66.446%
# 100%|██████████| 500/500 [00:01<00:00, 250.33it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1073.35it/s]
# INFO : Cross-entropy: 0.3857 nats (= perplexity 1.471)
# 100%|██████████| 996/996 [00:01<00:00, 859.16it/s]
# INFO : Tagging accuracy: all: 86.321%, known: 88.343%, seen: 62.795%, novel: 66.380%
# 100%|██████████| 500/500 [00:01<00:00, 259.38it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1071.86it/s]
# INFO : Cross-entropy: 0.3797 nats (= perplexity 1.462)
# 100%|██████████| 996/996 [00:01<00:00, 868.92it/s]
# INFO : Tagging accuracy: all: 87.002%, known: 89.126%, seen: 63.468%, novel: 65.588%
# 100%|██████████| 500/500 [00:02<00:00, 249.41it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1069.20it/s]
# INFO : Cross-entropy: 0.3747 nats (= perplexity 1.455)
# 100%|██████████| 996/996 [00:01<00:00, 862.70it/s]
# INFO : Tagging accuracy: all: 86.939%, known: 89.057%, seen: 62.626%, novel: 65.918%
# 100%|██████████| 500/500 [00:01<00:00, 256.37it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1060.71it/s]
# INFO : Cross-entropy: 0.3710 nats (= perplexity 1.449)
# 100%|██████████| 996/996 [00:01<00:00, 877.16it/s]
# INFO : Tagging accuracy: all: 87.741%, known: 89.932%, seen: 64.646%, novel: 65.192%
# 100%|██████████| 500/500 [00:02<00:00, 244.34it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1064.20it/s]
# INFO : Cross-entropy: 0.3695 nats (= perplexity 1.447)
# 100%|██████████| 996/996 [00:01<00:00, 879.39it/s]
# INFO : Tagging accuracy: all: 86.551%, known: 88.595%, seen: 63.300%, novel: 66.182%
# 100%|██████████| 500/500 [00:02<00:00, 246.41it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1068.19it/s]
# INFO : Cross-entropy: 0.3607 nats (= perplexity 1.434)
# 100%|██████████| 996/996 [00:01<00:00, 877.37it/s]
# INFO : Tagging accuracy: all: 87.816%, known: 90.129%, seen: 63.805%, novel: 63.871%
# 100%|██████████| 500/500 [00:01<00:00, 254.46it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1068.97it/s]
# INFO : Cross-entropy: 0.3556 nats (= perplexity 1.427)
# 100%|██████████| 996/996 [00:01<00:00, 881.83it/s]
# INFO : Tagging accuracy: all: 88.016%, known: 90.275%, seen: 63.300%, novel: 65.125%
# 100%|██████████| 500/500 [00:01<00:00, 253.72it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1067.61it/s]
# INFO : Cross-entropy: 0.3536 nats (= perplexity 1.424)
# 100%|██████████| 996/996 [00:01<00:00, 866.98it/s]
# INFO : Tagging accuracy: all: 87.544%, known: 89.685%, seen: 63.805%, novel: 65.984%
# 100%|██████████| 500/500 [00:01<00:00, 250.72it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1040.29it/s]
# INFO : Cross-entropy: 0.3462 nats (= perplexity 1.414)
# 100%|██████████| 996/996 [00:01<00:00, 866.44it/s]
# INFO : Tagging accuracy: all: 88.384%, known: 90.701%, seen: 62.458%, novel: 65.125%
# 100%|██████████| 500/500 [00:01<00:00, 253.50it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1066.11it/s]
# INFO : Cross-entropy: 0.3442 nats (= perplexity 1.411)
# 100%|██████████| 996/996 [00:01<00:00, 881.96it/s]
# INFO : Tagging accuracy: all: 88.254%, known: 90.408%, seen: 63.805%, novel: 66.777%
# 100%|██████████| 500/500 [00:01<00:00, 254.18it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1054.59it/s]
# INFO : Cross-entropy: 0.3417 nats (= perplexity 1.407)
# 100%|██████████| 996/996 [00:01<00:00, 860.63it/s]
# INFO : Tagging accuracy: all: 88.409%, known: 90.692%, seen: 63.300%, novel: 65.324%
# 100%|██████████| 500/500 [00:02<00:00, 241.92it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1044.55it/s]
# INFO : Cross-entropy: 0.3364 nats (= perplexity 1.400)
# 100%|██████████| 996/996 [00:01<00:00, 833.30it/s]
# INFO : Tagging accuracy: all: 88.722%, known: 90.925%, seen: 64.815%, novel: 66.314%
# 100%|██████████| 500/500 [00:02<00:00, 222.75it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1061.08it/s]
# INFO : Cross-entropy: 0.3343 nats (= perplexity 1.397)
# 100%|██████████| 996/996 [00:01<00:00, 891.90it/s]
# INFO : Tagging accuracy: all: 88.680%, known: 90.948%, seen: 64.141%, novel: 65.588%
# 100%|██████████| 500/500 [00:02<00:00, 229.70it/s]
# 100%|██████████| 996/996 [00:01<00:00, 958.99it/s]
# INFO : Cross-entropy: 0.3331 nats (= perplexity 1.395)
# 100%|██████████| 996/996 [00:01<00:00, 800.78it/s]
# INFO : Tagging accuracy: all: 88.521%, known: 90.742%, seen: 63.300%, novel: 66.380%
# 100%|██████████| 500/500 [00:02<00:00, 225.38it/s]
# 100%|██████████| 996/996 [00:01<00:00, 970.07it/s]
# INFO : Cross-entropy: 0.3281 nats (= perplexity 1.388)
# 100%|██████████| 996/996 [00:01<00:00, 817.64it/s]
# INFO : Tagging accuracy: all: 88.755%, known: 90.957%, seen: 65.320%, novel: 66.182%
# 100%|██████████| 500/500 [00:02<00:00, 232.72it/s]
# 100%|██████████| 996/996 [00:01<00:00, 971.76it/s]
# INFO : Cross-entropy: 0.3251 nats (= perplexity 1.384)
# 100%|██████████| 996/996 [00:01<00:00, 803.34it/s]
# INFO : Tagging accuracy: all: 89.169%, known: 91.566%, seen: 62.795%, novel: 64.927%
# 100%|██████████| 500/500 [00:02<00:00, 230.46it/s]
# 100%|██████████| 996/996 [00:01<00:00, 972.16it/s]
# INFO : Cross-entropy: 0.3231 nats (= perplexity 1.381)
# 100%|██████████| 996/996 [00:01<00:00, 811.15it/s]
# INFO : Tagging accuracy: all: 89.344%, known: 91.681%, seen: 64.310%, novel: 65.456%
# 100%|██████████| 500/500 [00:02<00:00, 230.01it/s]
# 100%|██████████| 996/996 [00:01<00:00, 969.34it/s]
# INFO : Cross-entropy: 0.3211 nats (= perplexity 1.379)
# 100%|██████████| 996/996 [00:01<00:00, 803.19it/s]
# INFO : Tagging accuracy: all: 89.106%, known: 91.333%, seen: 63.973%, novel: 66.843%
# 100%|██████████| 500/500 [00:02<00:00, 226.46it/s]
# 100%|██████████| 996/996 [00:01<00:00, 965.85it/s]
# INFO : Cross-entropy: 0.3174 nats (= perplexity 1.374)
# 100%|██████████| 996/996 [00:01<00:00, 820.67it/s]
# INFO : Tagging accuracy: all: 89.469%, known: 91.809%, seen: 62.963%, novel: 66.116%
# 100%|██████████| 500/500 [00:02<00:00, 223.60it/s]
# 100%|██████████| 996/996 [00:01<00:00, 970.12it/s]
# INFO : Cross-entropy: 0.3185 nats (= perplexity 1.375)
# 100%|██████████| 996/996 [00:01<00:00, 813.79it/s]
# INFO : Tagging accuracy: all: 88.755%, known: 90.962%, seen: 63.468%, novel: 66.843%
# 100%|██████████| 500/500 [00:02<00:00, 219.88it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1028.76it/s]
# INFO : Cross-entropy: 0.3148 nats (= perplexity 1.370)
# 100%|██████████| 996/996 [00:01<00:00, 864.28it/s]
# INFO : Tagging accuracy: all: 89.791%, known: 92.340%, seen: 62.626%, novel: 63.672%
# 100%|██████████| 500/500 [00:02<00:00, 234.13it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1029.51it/s]
# INFO : Cross-entropy: 0.3122 nats (= perplexity 1.366)
# 100%|██████████| 996/996 [00:01<00:00, 803.52it/s]
# INFO : Tagging accuracy: all: 89.135%, known: 91.470%, seen: 63.300%, novel: 65.588%
# 100%|██████████| 500/500 [00:02<00:00, 237.57it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1052.44it/s]
# INFO : Cross-entropy: 0.3103 nats (= perplexity 1.364)
# 100%|██████████| 996/996 [00:01<00:00, 866.01it/s]
# INFO : Tagging accuracy: all: 89.762%, known: 92.184%, seen: 62.963%, novel: 65.324%
# 100%|██████████| 500/500 [00:01<00:00, 253.42it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1057.94it/s]
# INFO : Cross-entropy: 0.3091 nats (= perplexity 1.362)
# 100%|██████████| 996/996 [00:01<00:00, 850.86it/s]
# INFO : Tagging accuracy: all: 90.175%, known: 92.610%, seen: 63.300%, novel: 65.588%
# 100%|██████████| 500/500 [00:02<00:00, 244.46it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1055.77it/s]
# INFO : Cross-entropy: 0.3068 nats (= perplexity 1.359)
# 100%|██████████| 996/996 [00:01<00:00, 865.40it/s]
# INFO : Tagging accuracy: all: 90.162%, known: 92.496%, seen: 63.468%, novel: 66.975%
# 100%|██████████| 500/500 [00:02<00:00, 240.08it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1011.29it/s]
# INFO : Cross-entropy: 0.3063 nats (= perplexity 1.358)
# 100%|██████████| 996/996 [00:01<00:00, 851.25it/s]
# INFO : Tagging accuracy: all: 90.079%, known: 92.651%, seen: 62.626%, novel: 63.738%
# 100%|██████████| 500/500 [00:02<00:00, 242.72it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1043.47it/s]
# INFO : Cross-entropy: 0.3105 nats (= perplexity 1.364)
# 100%|██████████| 996/996 [00:01<00:00, 843.83it/s]
# INFO : Tagging accuracy: all: 89.661%, known: 92.129%, seen: 62.121%, novel: 64.861%
# 100%|██████████| 500/500 [00:02<00:00, 244.55it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1037.22it/s]
# INFO : Cross-entropy: 0.3019 nats (= perplexity 1.352)
# 100%|██████████| 996/996 [00:01<00:00, 863.42it/s]
# INFO : Tagging accuracy: all: 89.983%, known: 92.313%, seen: 63.468%, novel: 66.777%
# 100%|██████████| 500/500 [00:02<00:00, 247.49it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1045.78it/s]
# INFO : Cross-entropy: 0.2992 nats (= perplexity 1.349)
# 100%|██████████| 996/996 [00:01<00:00, 853.06it/s]
# INFO : Tagging accuracy: all: 90.075%, known: 92.500%, seen: 63.131%, novel: 65.654%
# 100%|██████████| 500/500 [00:02<00:00, 246.64it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1050.09it/s]
# INFO : Cross-entropy: 0.3002 nats (= perplexity 1.350)
# 100%|██████████| 996/996 [00:01<00:00, 855.89it/s]
# INFO : Tagging accuracy: all: 89.699%, known: 92.038%, seen: 63.805%, novel: 66.116%
# 100%|██████████| 500/500 [00:02<00:00, 249.25it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1041.18it/s]
# INFO : Cross-entropy: 0.2991 nats (= perplexity 1.349)
# 100%|██████████| 996/996 [00:01<00:00, 848.79it/s]
# INFO : Tagging accuracy: all: 90.818%, known: 93.233%, seen: 63.973%, novel: 66.513%
# 100%|██████████| 500/500 [00:01<00:00, 252.04it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1065.33it/s]
# INFO : Cross-entropy: 0.2953 nats (= perplexity 1.344)
# 100%|██████████| 996/996 [00:01<00:00, 858.50it/s]
# INFO : Tagging accuracy: all: 89.874%, known: 92.175%, seen: 63.805%, novel: 66.909%
# 100%|██████████| 500/500 [00:02<00:00, 242.99it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1039.02it/s]
# INFO : Cross-entropy: 0.2936 nats (= perplexity 1.341)
# 100%|██████████| 996/996 [00:01<00:00, 860.60it/s]
# INFO : Tagging accuracy: all: 89.870%, known: 92.308%, seen: 62.626%, novel: 65.390%
# 100%|██████████| 500/500 [00:02<00:00, 238.69it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1044.48it/s]
# INFO : Cross-entropy: 0.2926 nats (= perplexity 1.340)
# 100%|██████████| 996/996 [00:01<00:00, 862.89it/s]
# INFO : Tagging accuracy: all: 90.104%, known: 92.546%, seen: 62.795%, novel: 65.588%
# 100%|██████████| 500/500 [00:02<00:00, 239.95it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1052.61it/s]
# INFO : Cross-entropy: 0.2907 nats (= perplexity 1.337)
# 100%|██████████| 996/996 [00:01<00:00, 867.45it/s]
# INFO : Tagging accuracy: all: 90.242%, known: 92.592%, seen: 63.636%, novel: 66.777%
# 100%|██████████| 500/500 [00:02<00:00, 243.36it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1055.47it/s]
# INFO : Cross-entropy: 0.2904 nats (= perplexity 1.337)
# 100%|██████████| 996/996 [00:01<00:00, 828.51it/s]
# INFO : Tagging accuracy: all: 90.430%, known: 92.803%, seen: 63.468%, novel: 66.777%
# 100%|██████████| 500/500 [00:02<00:00, 244.74it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1045.99it/s]
# INFO : Cross-entropy: 0.2878 nats (= perplexity 1.333)
# 100%|██████████| 996/996 [00:01<00:00, 850.11it/s]
# INFO : Tagging accuracy: all: 90.434%, known: 92.807%, seen: 63.300%, novel: 66.843%
# 100%|██████████| 500/500 [00:01<00:00, 250.28it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1045.40it/s]
# INFO : Cross-entropy: 0.2861 nats (= perplexity 1.331)
# 100%|██████████| 996/996 [00:01<00:00, 858.66it/s]
# INFO : Tagging accuracy: all: 90.709%, known: 93.224%, seen: 62.795%, novel: 65.390%
# 100%|██████████| 500/500 [00:01<00:00, 252.55it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1034.06it/s]
# INFO : Cross-entropy: 0.2892 nats (= perplexity 1.335)
# 100%|██████████| 996/996 [00:01<00:00, 867.99it/s]
# INFO : Tagging accuracy: all: 90.697%, known: 93.009%, seen: 64.141%, novel: 67.768%
# 100%|██████████| 500/500 [00:02<00:00, 237.90it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1005.21it/s]
# INFO : Cross-entropy: 0.2884 nats (= perplexity 1.334)
# 100%|██████████| 996/996 [00:01<00:00, 851.49it/s]
# INFO : Tagging accuracy: all: 90.296%, known: 92.583%, seen: 65.488%, novel: 67.041%
# 100%|██████████| 500/500 [00:02<00:00, 231.71it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1019.82it/s]
# INFO : Cross-entropy: 0.2862 nats (= perplexity 1.331)
# 100%|██████████| 996/996 [00:01<00:00, 843.92it/s]
# INFO : Tagging accuracy: all: 90.501%, known: 92.995%, seen: 62.795%, novel: 65.390%
# 100%|██████████| 500/500 [00:02<00:00, 238.91it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1031.92it/s]
# INFO : Cross-entropy: 0.2833 nats (= perplexity 1.328)
# 100%|██████████| 996/996 [00:01<00:00, 849.16it/s]
# INFO : Tagging accuracy: all: 90.730%, known: 93.096%, seen: 65.488%, novel: 66.513%
# 100%|██████████| 500/500 [00:02<00:00, 239.22it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1035.88it/s]
# INFO : Cross-entropy: 0.2832 nats (= perplexity 1.327)
# 100%|██████████| 996/996 [00:01<00:00, 850.18it/s]
# INFO : Tagging accuracy: all: 90.346%, known: 92.793%, seen: 62.963%, novel: 65.786%
# 100%|██████████| 500/500 [00:02<00:00, 242.56it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1039.63it/s]
# INFO : Cross-entropy: 0.2814 nats (= perplexity 1.325)
# 100%|██████████| 996/996 [00:01<00:00, 858.83it/s]
# INFO : Tagging accuracy: all: 90.567%, known: 93.064%, seen: 62.626%, novel: 65.522%
# 100%|██████████| 500/500 [00:02<00:00, 245.58it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1053.24it/s]
# INFO : Cross-entropy: 0.2806 nats (= perplexity 1.324)
# 100%|██████████| 996/996 [00:01<00:00, 856.14it/s]
# INFO : Tagging accuracy: all: 90.522%, known: 92.949%, seen: 63.131%, novel: 66.248%
# 100%|██████████| 500/500 [00:02<00:00, 234.84it/s]
# 100%|██████████| 996/996 [00:01<00:00, 881.94it/s]
# INFO : Cross-entropy: 0.2800 nats (= perplexity 1.323)
# 100%|██████████| 996/996 [00:01<00:00, 760.19it/s]
# INFO : Tagging accuracy: all: 90.588%, known: 93.068%, seen: 62.795%, novel: 65.720%
# 100%|██████████| 500/500 [00:02<00:00, 246.65it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1047.55it/s]
# INFO : Cross-entropy: 0.2778 nats (= perplexity 1.320)
# 100%|██████████| 996/996 [00:01<00:00, 858.55it/s]
# INFO : Tagging accuracy: all: 90.993%, known: 93.462%, seen: 63.468%, novel: 66.182%
# 100%|██████████| 500/500 [00:02<00:00, 242.81it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1019.81it/s]
# INFO : Cross-entropy: 0.2771 nats (= perplexity 1.319)
# 100%|██████████| 996/996 [00:01<00:00, 863.77it/s]
# INFO : Tagging accuracy: all: 90.722%, known: 93.160%, seen: 62.795%, novel: 66.513%
# 100%|██████████| 500/500 [00:01<00:00, 251.38it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1067.87it/s]
# INFO : Cross-entropy: 0.2772 nats (= perplexity 1.319)
# 100%|██████████| 996/996 [00:01<00:00, 862.32it/s]
# INFO : Tagging accuracy: all: 90.659%, known: 93.100%, seen: 63.636%, novel: 66.050%
# 100%|██████████| 500/500 [00:01<00:00, 251.92it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1039.45it/s]
# INFO : Cross-entropy: 0.2770 nats (= perplexity 1.319)
# 100%|██████████| 996/996 [00:01<00:00, 848.15it/s]
# INFO : Tagging accuracy: all: 90.981%, known: 93.453%, seen: 64.141%, novel: 65.852%
# 100%|██████████| 500/500 [00:01<00:00, 252.42it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1064.24it/s]
# INFO : Cross-entropy: 0.2749 nats (= perplexity 1.316)
# 100%|██████████| 996/996 [00:01<00:00, 865.92it/s]
# INFO : Tagging accuracy: all: 90.835%, known: 93.347%, seen: 62.626%, novel: 65.654%
# 100%|██████████| 500/500 [00:02<00:00, 244.56it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1057.19it/s]
# INFO : Cross-entropy: 0.2737 nats (= perplexity 1.315)
# 100%|██████████| 996/996 [00:01<00:00, 856.82it/s]
# INFO : Tagging accuracy: all: 91.060%, known: 93.581%, seen: 62.795%, novel: 65.786%
# 100%|██████████| 500/500 [00:02<00:00, 249.56it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1074.94it/s]
# INFO : Cross-entropy: 0.2737 nats (= perplexity 1.315)
# 100%|██████████| 996/996 [00:01<00:00, 841.40it/s]
# INFO : Tagging accuracy: all: 90.601%, known: 93.036%, seen: 63.805%, novel: 65.984%
# 100%|██████████| 500/500 [00:01<00:00, 253.70it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1065.34it/s]
# INFO : Cross-entropy: 0.2725 nats (= perplexity 1.313)
# 100%|██████████| 996/996 [00:01<00:00, 861.05it/s]
# INFO : Tagging accuracy: all: 91.102%, known: 93.558%, seen: 63.805%, novel: 66.380%
#  26%|██▌       | 129/500 [00:00<00:01, 259.23it/s]INFO : Saved model to ensup_crf-35640.pkl
# 100%|██████████| 500/500 [00:02<00:00, 242.15it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1070.84it/s]
# INFO : Cross-entropy: 0.2729 nats (= perplexity 1.314)
# 100%|██████████| 996/996 [00:01<00:00, 873.19it/s]
# INFO : Tagging accuracy: all: 90.985%, known: 93.439%, seen: 62.795%, novel: 66.645%
# 100%|██████████| 500/500 [00:01<00:00, 251.53it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1063.37it/s]
# INFO : Cross-entropy: 0.2768 nats (= perplexity 1.319)
# 100%|██████████| 996/996 [00:01<00:00, 865.16it/s]
# INFO : Tagging accuracy: all: 90.321%, known: 92.670%, seen: 63.805%, novel: 66.843%
# 100%|██████████| 500/500 [00:02<00:00, 247.67it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1071.33it/s]
# INFO : Cross-entropy: 0.2774 nats (= perplexity 1.320)
# 100%|██████████| 996/996 [00:01<00:00, 867.71it/s]
# INFO : Tagging accuracy: all: 90.104%, known: 92.459%, seen: 63.300%, novel: 66.645%
# 100%|██████████| 500/500 [00:02<00:00, 249.64it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1069.73it/s]
# INFO : Cross-entropy: 0.2739 nats (= perplexity 1.315)
# 100%|██████████| 996/996 [00:01<00:00, 872.46it/s]
# INFO : Tagging accuracy: all: 90.471%, known: 92.830%, seen: 63.636%, novel: 66.975%
# 100%|██████████| 500/500 [00:01<00:00, 253.18it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1073.61it/s]
# INFO : Cross-entropy: 0.2690 nats (= perplexity 1.309)
# 100%|██████████| 996/996 [00:01<00:00, 856.93it/s]
# INFO : Tagging accuracy: all: 91.411%, known: 93.906%, seen: 63.973%, novel: 66.182%
# 100%|██████████| 500/500 [00:01<00:00, 257.36it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1074.43it/s]
# INFO : Cross-entropy: 0.2684 nats (= perplexity 1.308)
# 100%|██████████| 996/996 [00:01<00:00, 856.48it/s]
# INFO : Tagging accuracy: all: 91.607%, known: 94.199%, seen: 63.805%, novel: 65.125%
# 100%|██████████| 500/500 [00:01<00:00, 252.42it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1070.64it/s]
# INFO : Cross-entropy: 0.2691 nats (= perplexity 1.309)
# 100%|██████████| 996/996 [00:01<00:00, 865.97it/s]
# INFO : Tagging accuracy: all: 91.515%, known: 94.016%, seen: 62.963%, novel: 66.645%
# 100%|██████████| 500/500 [00:01<00:00, 251.84it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1070.77it/s]
# INFO : Cross-entropy: 0.2673 nats (= perplexity 1.306)
# 100%|██████████| 996/996 [00:01<00:00, 875.28it/s]
# INFO : Tagging accuracy: all: 91.085%, known: 93.572%, seen: 63.131%, novel: 66.182%
# 100%|██████████| 500/500 [00:02<00:00, 248.74it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1065.39it/s]
# INFO : Cross-entropy: 0.2670 nats (= perplexity 1.306)
# 100%|██████████| 996/996 [00:01<00:00, 861.61it/s]
# INFO : Tagging accuracy: all: 91.119%, known: 93.613%, seen: 63.131%, novel: 66.116%
# 100%|██████████| 500/500 [00:01<00:00, 256.00it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1092.46it/s]
# INFO : Cross-entropy: 0.2668 nats (= perplexity 1.306)
# 100%|██████████| 996/996 [00:01<00:00, 870.31it/s]
# INFO : Tagging accuracy: all: 90.835%, known: 93.361%, seen: 62.458%, novel: 65.522%
# 100%|██████████| 500/500 [00:02<00:00, 246.46it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1070.43it/s]
# INFO : Cross-entropy: 0.2666 nats (= perplexity 1.306)
# 100%|██████████| 996/996 [00:01<00:00, 863.03it/s]
# INFO : Tagging accuracy: all: 91.281%, known: 93.801%, seen: 62.963%, novel: 66.050%
# 100%|██████████| 500/500 [00:01<00:00, 257.08it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1072.79it/s]
# INFO : Cross-entropy: 0.2672 nats (= perplexity 1.306)
# 100%|██████████| 996/996 [00:01<00:00, 856.13it/s]
# INFO : Tagging accuracy: all: 90.956%, known: 93.416%, seen: 63.636%, novel: 66.182%
# 100%|██████████| 500/500 [00:01<00:00, 256.77it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1073.97it/s]
# INFO : Cross-entropy: 0.2651 nats (= perplexity 1.304)
# 100%|██████████| 996/996 [00:01<00:00, 857.19it/s]
# INFO : Tagging accuracy: all: 91.519%, known: 94.080%, seen: 63.468%, novel: 65.588%
# 100%|██████████| 500/500 [00:02<00:00, 241.93it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1072.44it/s]
# INFO : Cross-entropy: 0.2645 nats (= perplexity 1.303)
# 100%|██████████| 996/996 [00:01<00:00, 866.57it/s]
# INFO : Tagging accuracy: all: 91.398%, known: 93.901%, seen: 64.141%, novel: 65.984%
# 100%|██████████| 500/500 [00:02<00:00, 244.72it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1068.41it/s]
# INFO : Cross-entropy: 0.2663 nats (= perplexity 1.305)
# 100%|██████████| 996/996 [00:01<00:00, 860.00it/s]
# INFO : Tagging accuracy: all: 90.960%, known: 93.375%, seen: 63.300%, novel: 66.975%
# 100%|██████████| 500/500 [00:01<00:00, 256.65it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1075.02it/s]
# INFO : Cross-entropy: 0.2620 nats (= perplexity 1.300)
# 100%|██████████| 996/996 [00:01<00:00, 851.32it/s]
# INFO : Tagging accuracy: all: 91.407%, known: 93.883%, seen: 63.300%, novel: 66.711%
# 100%|██████████| 500/500 [00:01<00:00, 259.42it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1062.76it/s]
# INFO : Cross-entropy: 0.2634 nats (= perplexity 1.301)
# 100%|██████████| 996/996 [00:01<00:00, 850.51it/s]
# INFO : Tagging accuracy: all: 91.311%, known: 93.860%, seen: 63.131%, novel: 65.588%
# 100%|██████████| 500/500 [00:02<00:00, 249.13it/s]
# 100%|██████████| 996/996 [00:00<00:00, 1067.30it/s]
# INFO : Cross-entropy: 0.2643 nats (= perplexity 1.303)
# 100%|██████████| 996/996 [00:01<00:00, 861.15it/s]
# INFO : Tagging accuracy: all: 90.977%, known: 93.393%, seen: 63.636%, novel: 66.843%
# 100%|██████████| 500/500 [00:02<00:00, 249.02it/s]
# 100%|██████████| 996/996 [00:01<00:00, 972.17it/s]
# INFO : Cross-entropy: 0.2609 nats (= perplexity 1.298)
# 100%|██████████| 996/996 [00:01<00:00, 803.77it/s]
# INFO : Tagging accuracy: all: 91.858%, known: 94.387%, seen: 63.468%, novel: 66.513%
# 100%|██████████| 500/500 [00:02<00:00, 231.14it/s]
# 100%|██████████| 996/996 [00:01<00:00, 954.08it/s]
# INFO : Cross-entropy: 0.2625 nats (= perplexity 1.300)
# 100%|██████████| 996/996 [00:01<00:00, 799.60it/s]
# INFO : Tagging accuracy: all: 91.173%, known: 93.668%, seen: 63.636%, novel: 65.984%
# 100%|██████████| 500/500 [00:02<00:00, 223.15it/s]
# 100%|██████████| 996/996 [00:01<00:00, 963.64it/s]
# INFO : Cross-entropy: 0.2619 nats (= perplexity 1.299)
# 100%|██████████| 996/996 [00:01<00:00, 782.96it/s]
# INFO : Tagging accuracy: all: 91.536%, known: 94.208%, seen: 63.300%, novel: 64.069%
# 100%|██████████| 500/500 [00:02<00:00, 228.27it/s]
# 100%|██████████| 996/996 [00:01<00:00, 974.03it/s]
# INFO : Cross-entropy: 0.2611 nats (= perplexity 1.298)
# 100%|██████████| 996/996 [00:01<00:00, 819.62it/s]
# INFO : Tagging accuracy: all: 91.365%, known: 93.878%, seen: 62.458%, novel: 66.446%
# 100%|██████████| 500/500 [00:02<00:00, 220.42it/s]
# 100%|██████████| 996/996 [00:01<00:00, 934.99it/s]
# INFO : Cross-entropy: 0.2611 nats (= perplexity 1.298)
# 100%|██████████| 996/996 [00:01<00:00, 826.97it/s]
# INFO : Tagging accuracy: all: 91.649%, known: 94.222%, seen: 63.468%, novel: 65.588%
# 100%|██████████| 500/500 [00:02<00:00, 222.94it/s]
# 100%|██████████| 996/996 [00:01<00:00, 956.31it/s]
# INFO : Cross-entropy: 0.2648 nats (= perplexity 1.303)
# 100%|██████████| 996/996 [00:01<00:00, 808.45it/s]
# INFO : Tagging accuracy: all: 91.770%, known: 94.478%, seen: 62.963%, novel: 64.003%
# 100%|██████████| 500/500 [00:02<00:00, 228.91it/s]
# 100%|██████████| 996/996 [00:01<00:00, 968.41it/s]
# INFO : Cross-entropy: 0.2607 nats (= perplexity 1.298)
# 100%|██████████| 996/996 [00:01<00:00, 812.35it/s]
# INFO : Tagging accuracy: all: 91.173%, known: 93.695%, seen: 62.626%, novel: 65.984%
# 100%|██████████| 500/500 [00:02<00:00, 224.03it/s]
# 100%|██████████| 996/996 [00:01<00:00, 972.58it/s]
# INFO : Cross-entropy: 0.2593 nats (= perplexity 1.296)
# 100%|██████████| 996/996 [00:01<00:00, 807.38it/s]
# INFO : Tagging accuracy: all: 91.657%, known: 94.176%, seen: 64.141%, novel: 66.116%
# 100%|██████████| 500/500 [00:02<00:00, 223.00it/s]
# 100%|██████████| 996/996 [00:01<00:00, 947.19it/s]
# INFO : Cross-entropy: 0.2581 nats (= perplexity 1.294)
# 100%|██████████| 996/996 [00:01<00:00, 819.52it/s]
# INFO : Tagging accuracy: all: 91.737%, known: 94.272%, seen: 63.131%, novel: 66.380%
# 100%|██████████| 500/500 [00:02<00:00, 232.19it/s]
# 100%|██████████| 996/996 [00:01<00:00, 972.51it/s]
# INFO : Cross-entropy: 0.2577 nats (= perplexity 1.294)
# 100%|██████████| 996/996 [00:01<00:00, 805.78it/s]
# INFO : Tagging accuracy: all: 91.528%, known: 94.158%, seen: 63.468%, novel: 64.597%
# 100%|██████████| 500/500 [00:02<00:00, 224.79it/s]
# 100%|██████████| 996/996 [00:01<00:00, 959.85it/s]
# INFO : Cross-entropy: 0.2618 nats (= perplexity 1.299)
# 100%|██████████| 996/996 [00:01<00:00, 824.13it/s]
# INFO : Tagging accuracy: all: 90.956%, known: 93.361%, seen: 63.973%, novel: 66.843%
# INFO : Saved model to ensup_crf.pkl

# %% [markdown]
# Let's examine how the CRF does on individual sentences.
# (Do you see any error patterns here that would inspire additional CRF features?)

# %%
look_at_your_data(crf, endev, 10)
# Out:
# INFO : Gold:    ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/N this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/N added/V ,/, ``/` and/C that/D means/V virtually/R everyone/N who/W works/V here/R ./.
# INFO : Viterbi: ``/` We/P 're/V strongly/N _OOV_/N that/I anyone/N who/W has/V eaten/N in/I the/D cafeteria/N this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/N added/V ,/, ``/` and/C that/I means/N virtually/N everyone/N who/W works/V here/R ./.
# INFO : Loss:    6/34
# INFO : Cross-entropy: 0.49772173166275024 nats (= perplexity 1.411982048938138)
# ---
# INFO : Gold:    I/P was/V _OOV_/V to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/N ``/` _OOV_/N 's/P _OOV_/N _OOV_/N ./. ''/'
# INFO : Viterbi: I/P was/V _OOV_/V to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/N ``/` _OOV_/N 's/P _OOV_/N _OOV_/N ./. ''/'
# INFO : Loss:    0/21
# INFO : Cross-entropy: 0.2624722123146057 nats (= perplexity 1.199532464784383)
# ---
# INFO : Gold:    It/P is/V the/D _OOV_/J guerrillas/N who/W are/V aligned/V with/I the/D drug/N traffickers/N ,/, not/R the/D left/J _OOV_/N ./.
# INFO : Viterbi: It/P is/V the/D _OOV_/N guerrillas/N who/W are/V aligned/N with/I the/D drug/N traffickers/N ,/, not/R the/D left/N _OOV_/N ./.
# INFO : Loss:    3/18
# INFO : Cross-entropy: 0.33159464597702026 nats (= perplexity 1.2584035573076913)
# ---
# INFO : Gold:    This/D information/N was/V _OOV_/V from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Viterbi: This/D information/N was/V _OOV_/N from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Loss:    1/13
# INFO : Cross-entropy: 0.17914226651191711 nats (= perplexity 1.1322105462126868)
# ---
# INFO : Gold:    _OOV_/J _OOV_/J government/N _OOV_/N of/I the/D ``/` _OOV_/F ''/' was/V due/J to/T the/D drug/N _OOV_/N '/P history/N of/I _OOV_/V out/R _OOV_/N in/I the/D _OOV_/N ./.
# INFO : Viterbi: _OOV_/N _OOV_/N government/N _OOV_/N of/I the/D ``/` _OOV_/N ''/' was/V due/J to/T the/D drug/N _OOV_/N '/P history/N of/I _OOV_/N out/I _OOV_/N in/I the/D _OOV_/N ./.
# INFO : Loss:    5/25
# INFO : Cross-entropy: 0.8080924153327942 nats (= perplexity 1.750894780272716)
# ---
# INFO : Gold:    Mary/N _OOV_/N Palo/N Alto/N ,/, Calif/N ./.
# INFO : Viterbi: Mary/N _OOV_/N Palo/N Alto/N ,/, Calif/N ./.
# INFO : Loss:    0/7
# INFO : Cross-entropy: 0.18952824175357819 nats (= perplexity 1.1403907441060952)
# ---
# INFO : Gold:    I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/R well/R as/I other/J U.S./N news/N publications/N of/I like/J mind/N -RRB-/- should/M put/V its/P money/N where/W its/P mouth/N is/V :/: _OOV_/V computer/N equipment/N to/T replace/V that/I damaged/V at/I El/N _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/N _OOV_/N journalists/N ./.
# INFO : Viterbi: I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/I well/R as/I other/J U.S./N news/N publications/N of/I like/I mind/N -RRB-/- should/M put/V its/P money/N where/W its/P mouth/N is/V :/: _OOV_/N computer/N equipment/N to/T replace/V that/I damaged/V at/I El/N _OOV_/N ,/, buy/V ad/N space/N ,/, publish/N stories/N under/I the/D _OOV_/N of/I El/N _OOV_/N journalists/N ./.
# INFO : Loss:    4/53
# INFO : Cross-entropy: 0.37928861379623413 nats (= perplexity 1.300700318649723)
# ---
# INFO : Gold:    Perhaps/R an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/V ''/' El/N _OOV_/N journalists/N and/C staff/N by/I paying/V for/I added/V security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Viterbi: Perhaps/I an/D arrangement/N could/M be/V worked/V out/I to/T ``/` sponsor/N ''/' El/N _OOV_/N journalists/N and/C staff/N by/I paying/V for/I added/J security/N in/I exchange/N for/I exclusive/N stories/N ./.
# INFO : Loss:    5/27
# INFO : Cross-entropy: 0.49574270844459534 nats (= perplexity 1.4100464606692102)
# ---
# INFO : Gold:    _OOV_/V El/N _OOV_/N 's/P courage/N with/I real/J support/N ./.
# INFO : Viterbi: _OOV_/N El/N _OOV_/N 's/P courage/N with/I real/J support/N ./.
# INFO : Loss:    1/9
# INFO : Cross-entropy: 0.7054070234298706 nats (= perplexity 1.6306046683123714)
# ---
# INFO : Gold:    Douglas/N B./N Evans/N
# INFO : Viterbi: Douglas/N B./N Evans/N
# INFO : Loss:    0/3
# INFO : Cross-entropy: 0.24998407065868378 nats (= perplexity 1.189193984701383)
# ---
